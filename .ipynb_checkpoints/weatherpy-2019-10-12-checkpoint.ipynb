# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

#import API-Keys
#from api_keys import weather_api_keys
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

output_citi_file = "Pournima API Homework.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)


# List for holding lat_lngs and cities
lat_lngs = []
list_of_cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in list_of_cities:
        list_of_cities.append(city)

# Print the city count to confirm sufficient count
len(list_of_cities)
#print(cities[0])
# Out:
# 634

# %%
nbr_of_cities_processed = 0

#Export data into.csv
csvfile = open(output_citi_file, "w+")

for current_city in list_of_cities:

    weather_url = f"http://api.openweathermap.org/data/2.5/weather?q={current_city}&appid={api_key}"
    print (weather_url)
    try:            
        print(f"Processing Record {nbr_of_cities_processed} {current_city}")
        response = requests.get(weather_url)
        response_json = response.json()
        #print(type(response_json))
        #print(f"The response is{json.dumps(response_json,indent=2)}.")
      
        latitude = response_json["coord"]["lat"]
        longitude = response_json["coord"]["lon"]
        wind_speed =  response_json["wind"]["speed"]  
        cloudiness =  response_json["clouds"]["all"]  
        Humidity =  response_json["main"]["humidity"]  
        Temparature =response_json["main"]["temp"]
        
        print(f"{nbr_of_cities_processed},{current_city},{cloudiness},some_country,2019-01-01,{Humidity},{latitude},{longitude},{Temparature},{wind_speed}", file=csvfile)
        nbr_of_cities_processed +=1
        if nbr_of_cities_processed > 5:
            break

    except KeyError:
        print(f"city_name {current_city} not found")    

csvfile.close()
# Out:
# http://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=3038bf3f3cd82b7422595ba61cbf0e46
# Processing Record 0 new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=lebu&appid=3038bf3f3cd82b7422595ba61cbf0e46
# Processing Record 1 lebu
# http://api.openweathermap.org/data/2.5/weather?q=dikson&appid=3038bf3f3cd82b7422595ba61cbf0e46
# Processing Record 2 dikson
# http://api.openweathermap.org/data/2.5/weather?q=hirapur&appid=3038bf3f3cd82b7422595ba61cbf0e46
# Processing Record 3 hirapur
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=3038bf3f3cd82b7422595ba61cbf0e46
# Processing Record 4 cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&appid=3038bf3f3cd82b7422595ba61cbf0e46
# Processing Record 5 kaitangata

# %%
datafile = 'Provided City weather data.csv'

# %%
citi_df = pd.read_csv(datafile)
citi_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
plt.scatter(citi_df.iloc[:,6], citi_df.iloc[:,8])
plt.xlabel('Latitude')
plt.ylabel('Max Temparatur')
plt.title('City Latitude VS Max Temparature')
plt.savefig("Citi Lat and Temp.png")
plt.show()

# %%
# the further you go from equator the temp is lower.

# %%
plt.scatter(citi_df.iloc[:,6], citi_df.iloc[:,5])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude VS Humidity')
plt.savefig("Citi Lat and Humiditi.png")

plt.show()

# %%
# Data has a outlier. There is no relation between Latitude and Humidity.

# %%
plt.scatter(citi_df.iloc[:,6], citi_df.iloc[:,2])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude VS Cloudiness')
plt.savefig("Citi Lat and Cloudiness.png")

plt.show()

# %%
#There is no relation between cloudiness and Latitude.

# %%
plt.scatter(citi_df.iloc[:,6], citi_df.iloc[:,9])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude VS Wind Speed')
plt.savefig("Citi Lat and Wind Speed.png")

plt.show()

# %%
# wind speed is mostly between 0 to 20 regardless of latitude.

# %%
North_Cities_df = citi_df.loc[citi_df["Lat"] >= 0]

North_Lat = North_Cities_df['Lat']
Max_temp = North_Cities_df['Max Temp']
humidity = North_Cities_df['Humidity']
cloudiness = North_Cities_df['Cloudiness']
wind_speed = North_Cities_df['Wind Speed']

# %%
plt.scatter(North_Lat, Max_temp)
x_values = North_Lat
y_values = Max_temp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temparature')
plt.title('City Latitude VS Max Temparature')
plt.savefig("North Lat Max Temp Cities.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8151657406810829

# %%
# with this is graph we can tell there is a positive relation between Latitude and temp. closer to the latitude temp is high.

# %%
#separating as per Northern Latitude(greater than equal to 0 degree latitude)
#North_Lat = citi_df.loc[citi_df["Lat"] >= 0]
            
#North_Lat.head()

# %%
# plt.scatter(North_Lat.iloc[:,6],North_Lat.iloc[:,8])
# plt.xlabel('Latitude')
# plt.ylabel('Max Temparatur')
# plt.title('City Latitude VS Max Temparature')
# plt.savefig("North Lat Max Temp Cities.png")
# plt.show()

# %%
plt.scatter(North_Lat, humidity)
x_values = North_Lat
y_values = humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude VS Humidity')
plt.savefig("North Lat Humidity.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.10358336015746496

# %%
# There is no relation between Humidity and Latitude.

# %%
# plt.scatter(North_Lat.iloc[:,6], North_Lat.iloc[:,5])
# plt.xlabel('Latitude')
# plt.ylabel('Humidity')
# plt.title('City Latitude VS Humidity')
# plt.savefig("North Lat Humiditi Cities.png")
# plt.show()

# %%
plt.scatter(North_Lat, cloudiness)
x_values = North_Lat
y_values = cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude VS Cloudiness')
plt.savefig("North Lat Cloudiness.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.08733547918934018

# %%
# There is no co relation between cloudiness and Latitude.

# %%
# plt.scatter(North_Lat.iloc[:,6],North_Lat.iloc[:,2])
# plt.xlabel('Latitude')
# plt.ylabel('Cloudiness')
# plt.title('City Latitude VS Cloudiness')
# plt.savefig("North Lat Cloudiness Cities.png")
# plt.show()

# %%
plt.scatter(North_Lat, wind_speed)
x_values = North_Lat
y_values = wind_speed
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude VS Wind Speed')
plt.savefig("North Lat Windspeed.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.10713827743884798

# %%
#There is no corelation between Latitude and wind speed

# %%
South_Cities_df = citi_df.loc[citi_df["Lat"] <= 0]

South_Lat = South_Cities_df['Lat']
Max_temp = South_Cities_df['Max Temp']
humidity = South_Cities_df['Humidity']
cloudiness = South_Cities_df['Cloudiness']
wind_speed = South_Cities_df['Wind Speed']

# %%
plt.scatter(South_Lat, Max_temp)
x_values = South_Lat
y_values = Max_temp
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temparature')
plt.title('City Latitude VS Max Temparature')
plt.savefig("South Lat Max Temp Cities.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.7602633550516462

# %%
#There is a positive relation between temp & Latitude. Closer to latitude the temp is higher.

# %%
plt.scatter(South_Lat, humidity)
x_values = South_Lat
y_values = humidity
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude VS Humidity')
plt.savefig("South Lat Humidity.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.14689473425583074

# %%
# There is no relation between Humidity and Latitude.There is an outlier.

# %%
plt.scatter(South_Lat, cloudiness)
x_values = South_Lat
y_values = cloudiness
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude VS Cloudiness')
plt.savefig("South Lat Cloudiness.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.21881426893991604

# %%
#There is no corelation between Latitude and cloudiness.

# %%
plt.scatter(South_Lat, wind_speed)
x_values = South_Lat
y_values = wind_speed
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('City Latitude VS Wind Speed')
plt.savefig("South Lat Windspeed.png")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.3224830771395381

# %%
# They are some what related to each other.
